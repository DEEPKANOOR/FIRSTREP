# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'https://raw.githubusercontent.com/dsrscientist/dataset1/master/abalone.csv')

# %%
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.shape
# Out:
# (4177, 9)

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.isna().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df['Rings'].value_counts()
# Out:
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 27      2
# 24      2
# 1       1
# 26      1
# 29      1
# 2       1
# 25      1
# Name: Rings, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (4177, 9)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Sex']= le.fit_transform(df['Sex'])

# %%
le.inverse_transform([2,1,0])
# Out:
# array(['M', 'I', 'F'], dtype=object)

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4172    0   0.565     0.450   0.165        0.8870          0.3700
# 4173    2   0.590     0.440   0.135        0.9660          0.4390
# 4174    2   0.600     0.475   0.205        1.1760          0.5255
# 4175    0   0.625     0.485   0.150        1.0945          0.5310
# 4176    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
count =1
plt.figure(figsize=(15,15),facecolor='orange')
for i in df:
    plt.subplot(3,3,count)
    sns.distplot(df[i])
    plt.xlabel(i)
    count+=1
    plt.tight_layout

# %%
count =1
plt.figure(figsize=(15,15),facecolor='orange')
for i in df:
    plt.subplot(3,3,count)
    sns.boxplot(df[i])
    plt.xlabel(i)
    count+=1
    plt.tight_layout

# %%
from scipy.stats import zscore

# %%
(np.abs(zscore(df)<3)).all()
# Out:
# Sex                True
# Length             True
# Diameter           True
# Height            False
# Whole weight      False
# Shucked weight    False
# Viscera weight    False
# Shell weight      False
# Rings             False
# dtype: bool

# %%
ind=[]
ind = np.where(np.abs(zscore(df['Height'])>3))
print(ind)
df.drop(df.index[ind], inplace = True)
df.reset_index(drop = True, inplace = True)
# Out:
# (array([1417, 2051], dtype=int64),)

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4170    0   0.565     0.450   0.165        0.8870          0.3700
# 4171    2   0.590     0.440   0.135        0.9660          0.4390
# 4172    2   0.600     0.475   0.205        1.1760          0.5255
# 4173    0   0.625     0.485   0.150        1.0945          0.5310
# 4174    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
ind1 = []
ind1 = np.where(np.abs(zscore(df['Whole weight'])>3))
print(ind1)
df.drop(df.index[ind1],inplace = True)
df.reset_index(inplace = True, drop = True)
# Out:
# (array([1417, 2051], dtype=int64),)

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4151    0   0.565     0.450   0.165        0.8870          0.3700
# 4152    2   0.590     0.440   0.135        0.9660          0.4390
# 4153    2   0.600     0.475   0.205        1.1760          0.5255
# 4154    0   0.625     0.485   0.150        1.0945          0.5310
# 4155    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
ind2 = []
ind2 = np.where(np.abs(zscore(df['Shucked weight'])>3))
print(ind2)
df.drop(df.index[ind2], inplace = True)
df.reset_index(drop = True,inplace = True)
# Out:
# (array([1045, 1188, 1192, 1194, 1197, 1201, 1410, 1418, 1518, 1519, 1745,
#        1747, 1752, 1810, 1971, 2531, 2610, 2660, 2695, 2795, 2846, 2990,
#        3065, 3694, 3940, 3941], dtype=int64),)

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4125    0   0.565     0.450   0.165        0.8870          0.3700
# 4126    2   0.590     0.440   0.135        0.9660          0.4390
# 4127    2   0.600     0.475   0.205        1.1760          0.5255
# 4128    0   0.625     0.485   0.150        1.0945          0.5310
# 4129    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
ind3 = []
ind3 = np.where(np.abs(zscore(df['Viscera weight'])>3))
print(ind3)
df.drop(df.index[ind3], inplace = True)
df.reset_index(inplace = True, drop = True)
# Out:
# (array([ 169, 1194, 1407, 1736, 1738, 2676, 3586, 4101], dtype=int64),)

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4117    0   0.565     0.450   0.165        0.8870          0.3700
# 4118    2   0.590     0.440   0.135        0.9660          0.4390
# 4119    2   0.600     0.475   0.205        1.1760          0.5255
# 4120    0   0.625     0.485   0.150        1.0945          0.5310
# 4121    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
ind4 = []
ind4 = np.where(np.abs(zscore(df['Shell weight'])>3))
print(ind4)
df.drop(df.index[ind4], inplace = True)
df.reset_index(inplace = True, drop = True)
# Out:
# (array([  81,  129,  163,  164,  165,  166,  167,  275,  332, 1408, 1793,
#        1954, 2058, 2076, 2125, 2129, 2176, 2242, 2335, 2963, 3102, 3103,
#        3105, 3142, 3876, 4091], dtype=int64),)

# %%
df
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0       2   0.455     0.365   0.095        0.5140          0.2245
# 1       2   0.350     0.265   0.090        0.2255          0.0995
# 2       0   0.530     0.420   0.135        0.6770          0.2565
# 3       2   0.440     0.365   0.125        0.5160          0.2155
# 4       1   0.330     0.255   0.080        0.2050          0.0895
# ...   ...     ...       ...     ...           ...             ...
# 4091    0   0.565     0.450   0.165        0.8870          0.3700
# 4092    2   0.590     0.440   0.135        0.9660          0.4390
# 4093    2   0.600     0.475   0.205        1.1760          0.5255
# 4094    0   0.625     0.485   0.150        1.0945          0.5310
# 4095    2   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
(np.abs(zscore(df)<3)).all()
# Out:
# Sex                True
# Length             True
# Diameter           True
# Height            False
# Whole weight      False
# Shucked weight    False
# Viscera weight    False
# Shell weight      False
# Rings             False
# dtype: bool

# %%
count =1
plt.figure(figsize=(15,15),facecolor='orange')
for i in df:
    plt.subplot(3,3,count)
    sns.boxplot(df[i])
    plt.xlabel(i)
    count+=1
    plt.tight_layout

# %%
df.skew()

# %%
df.corr()

# %%
sns.heatmap(df.corr(),annot = True)

# %%
df.corr()>0.75

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
y=df['Rings']

# %%
vif=pd.DataFrame({})
vif['vif']=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
vif['columns']= x.columns
vif

# %%
(df==0).value_counts()

# %%
from sklearn.
